# %% [markdown]
# First program
#
# **first prg
# **

# %%
print("i am rishab")
# Out:
# i am rishab

# %% [markdown]
# variable declaration in python

# %%
a=5
b=9
sum=a+b
print(sum)
print("sum")
# Out:
# 14
# sum

# %%
a=10
b=5
sub=a-b
print(sub)
print("sub")
# Out:
# 5
# sub

# %%
a=15
b=10
c=5
sub=a-b-c
print(sub)
print("sub")
# Out:
# 0
# sub

# %%
a=5
b=2
sqr=(a**b)+(b**a)
print(sqr)
print("sqr")
# Out:
# 57
# sqr

# %%
import math
print(math.sqrt(3))
# Out:
# 1.7320508075688772

# %%
set1 ={"red","blue"}
print(set1)
set1.add('chrome')
print(set1)
set2={"yellow","bike"}
set1.update(set2)
print(set1)
# Out:
# {'blue', 'red'}
# {'chrome', 'blue', 'red'}
# {'yellow', 'blue', 'chrome', 'bike', 'red'}

# %%
a=input("Enter the value of a")
b=input("Enter the value of b")
print(a)
print(b)
# Out:
# Enter the value of a2
# Enter the value of b3
# 2
# 3

# %%
if a>b:
  print("The value of a is greater than b")
if a==b:
  print("The value of a and b are same")
else:
  print("The value of b is greater than a")
# Out:
# The value of b is greater than a

# %%
ball1_colour="green"
ball2_colour="red"
ball3_colour="white"
pick_ball=input("Please pick a ball")
if pick_ball == ball1_colour:
  print("Green ball is picked")

elif pick_ball == ball2_colour:
  print("Red ball is picked")

else:
  print("White ball is picked")
# Out:
# Please pick a ballred
# Red ball is picked

# %%
from ast import Yield
x=2
y=2

sum=x+y
diff=x-y
prod=x*y
div=x/y
fdiv=x//y
mod=x%y
power=x**y
print(sum)
print(diff)
print(prod)
print(div)
print(fdiv)
print(mod)
print(power)
# Out:
# 4
# 0
# 4
# 1.0
# 1
# 0
# 4

# %%
 age=int(input("Enter the age"))
 print(age>18 and age<30)
 print(age>1 and age<16)
# Out:
# Enter the age17
# False
# False

# %%
print(8|14)
print(0x1&0x2)
# Out:
# 14
# 0

# %%
print(8>>2)
print(8>>1)
# Out:
# 2
# 4

# %%
print(8<<2)
print(8<<1)
# Out:
# 32
# 16

# %%
a=5
print(a)
a+=5
print(a)
a*=2
print(a)
a%=5
print(a)
# Out:
# 5
# 10
# 20
# 0

# %%
x=["Hubli","Belgaum"]
y=["Hubli","Belgaum"]
z=x
z=y
print(z is not x)
print(z is y)
# Out:
# True
# True

# %%
num=int(input("Enter the number"))
while num>=0 and num<=9:
  print("Number is single digit")
  break
else:
  print("Number is more than two digit")
while num>9 and num<=99:
  print("Number is double digit")
  break
# Out:
# Enter the number33
# Number is more than two digit
# Number is double digit

# %%
def cake_baker(p,f,s):
  print("Number of pieces=",p)
  print("Flavour of the cake =",f)
  print("Size of the cake=",s)

cake_baker("4","Choco lava","1kg")
cake_baker("6","White forest","2kg")
# Out:
# Number of pieces= 4
# Flavour of the cake = Choco lava
# Size of the cake= 1kg
# Number of pieces= 6
# Flavour of the cake = White forest
# Size of the cake= 2kg

# %%
def add(*args):
  sum=0
  for i in args:
    sum+=i
  return sum
print(add(1,2,3,4,5))
# Out:
# 15

# %%
def greet(**kwargs):
  print("Hello")
  for key,value in kwargs.items():
     print(value,end="  ")

greet(name="Name - Rishab", usn="Usn - 01fe21bec216", branch="Branch - EC")
# Out:
# Hello
# Name - Rishab  Usn - 01fe21bec216  Branch - EC

# %%
import random

computer=random.randint(1,10)
userinput=int(input("Enter the number between 1 and 10"))
print(computer)
print(userinput)

if computer>userinput:
  print("Computer won")
elif computer==userinput:
  print("Tie")
else :
  print("You won")
# Out:
# Enter the number between 1 and 109
# 4
# 9
# You won

# %%
import random

gamelist=['rock','paper','scissors']
comp=random.choice(gamelist)
user=input("Enter either rock or paper or scissors  ")
print(comp)
print(user)

if(comp=="rock" and user=="paper"):
  print("Computer won")
elif(comp=="paper" and user=="rock"):
  print("You won")
elif(comp=="paper" and user=="scissors"):
  print("You won")
elif(comp=="scissors" and user=="paper"):
  print("Computer won")
elif(comp=="rock" and user=="scissors"):
  print("Computer won")
elif(comp=="scissors" and user=="rock"):
  print("You won")
# Out:
# Enter either rock or paper or scissors  rock
# scissors
# rock
# You won

# %%
import numpy as np

# %%
a=np.array([35,1,34,36,27,48,49])
print(type(a))

b=np.zeros(3)
c=np.ones(4)

print(b)
print(c)

d=np.sort(a)
print(d)
# Out:
# <class 'numpy.ndarray'>
# [0. 0. 0.]
# [1. 1. 1. 1.]
# [ 1 27 34 35 36 48 49]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
x = np.linspace(0,10,100)
y = 6+3*np.sin(x)

# plot
fig,a = plt.subplots()

a.plot(x,y,linewidth=2.0)

a.set(xlim=(0,8), xticks=np.arrange(1,8),
      ylim=(0,8), yticks=np.arrange(1,8))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-b296b8b281b5> in <cell line: 15>()
#      13 a.plot(x,y,linewidth=2.0)
#      14
# ---> 15 a.set(xlim=(0,8), xticks=np.arrange(1,8),
#      16       ylim=(0,8), yticks=np.arrange(1,8))
#      17
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     309             return Tester
#     310
# --> 311         raise AttributeError("module {!r} has no attribute "
#     312                              "{!r}".format(__name__, attr))
#     313
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
import matplotlib.pyplot as plt
import numpy as np
Temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
Res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])

plt.scatter(Temp,Res)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
Temp=np.array([10,20,25,30,40,50,60,70,80,90,100,110,120])
Res=np.array([18476,12185,10000,8260,5740,4080,2960,2188,1645,1257,973,765,608])
plt.title("Thermistor characteristics")
plt.xlabel("Temperature")
plt.ylabel("Resistance")

plt.plot(Temp,Res)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["Karnataka","Maharashtra","Goa"])
y=np.array([50,60,40])

plt.bar(x,y)
plt.show()


plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.normal(5,1,10000)

plt.hist(x,100)
plt.show()

# %%
import pandas as pd

data=pd.read_csv('/content/sample_data/california_housing_test.csv')
print(data.to_string)
# Out:
# <bound method DataFrame.to_string of       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('/content/drive/MyDrive/data.csv - Sheet1.csv')

df.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,5,13,25,33,46]).reshape((-1,1))
y=np.array([3,6,15,12,21,18])

# %%
plt.scatter(x,y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
SLR=LinearRegression()

# %%
SLR.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=SLR.predict(x)

# %%
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red', marker='*')

print("MSE:", mse)
print("intercept:", SLR.intercept_)
print("slope:", SLR.coef_)
# Out:
# MSE: 11.247422680412372
# intercept: 5.525773195876288
# slope: [0.34020619]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.random.randint(1,50,7).reshape((-1,1))
y=np.random.randint(1,50,7)
plt.scatter(x,y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('/content/drive/MyDrive/data.csv - Sheet1.csv')

df.plot()
# Out:
# <Axes: >

# %%
x=df['Duration']
x=x.values.reshape((-1,1))
y=df['Pulse']
#print(x)
#print(y)
plt.scatter(x,y)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)

from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red', marker='*')

print("MSE:", mse)
print("intercept:", SLR.intercept_)
print("slope:", SLR.coef_)
# Out:
# MSE: 0.16666666666666669
# intercept: 1.178932178932179
# slope: [1.15440115]
